# %%
# !pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf

import pandas as pd

# %%
shell = yf.Ticker("SHEL.L")

# %%
shell.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
shell = shell.history(period="max")

# %%
shell
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1996-08-29 00:00:00+01:00  3645.669678  3666.394889  3625.814378  3645.669678
# 1996-08-30 00:00:00+01:00  3586.582520  3614.415663  3580.673638  3586.582520
# 1996-09-02 00:00:00+01:00  3632.231934  3631.512133  3600.469174  3632.231934
# 1996-09-03 00:00:00+01:00  3627.405518  3646.091057  3617.777537  3627.405518
# 1996-09-04 00:00:00+01:00  3694.797119  3709.193498  3680.400374  3694.797119
# ...                                ...          ...          ...          ...
# 2024-08-23 00:00:00+01:00  2715.000000  2722.500000  2707.500000  2720.000000
# 2024-08-27 00:00:00+01:00  2755.000000  2761.729980  2721.500000  2725.000000
# 2024-08-28 00:00:00+01:00  2720.000000  2722.500000  2680.500000  2696.000000
# 2024-08-29 00:00:00+01:00  2691.000000  2718.761963  2670.500000  2711.000000
# 2024-08-30 00:00:00+01:00  2726.000000  2729.500000  2669.000000  2681.000000
#
# ...

# %%
shell.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits    float64
# dtype: object

# %%
shell.index
# Out:
# DatetimeIndex(['1996-08-29 00:00:00+01:00', '1996-08-30 00:00:00+01:00',
#                '1996-09-02 00:00:00+01:00', '1996-09-03 00:00:00+01:00',
#                '1996-09-04 00:00:00+01:00', '1996-09-05 00:00:00+01:00',
#                '1996-09-06 00:00:00+01:00', '1996-09-09 00:00:00+01:00',
#                '1996-09-10 00:00:00+01:00', '1996-09-11 00:00:00+01:00',
#                ...
#                '2024-08-16 00:00:00+01:00', '2024-08-19 00:00:00+01:00',
#                '2024-08-20 00:00:00+01:00', '2024-08-21 00:00:00+01:00',
#                '2024-08-22 00:00:00+01:00', '2024-08-23 00:00:00+01:00',
#                '2024-08-27 00:00:00+01:00', '2024-08-28 00:00:00+01:00',
#                '2024-08-29 00:00:00+01:00', '2024-08-30 00:00:00+01:00'],
#               dtype='datetime64[ns, Europe/London]', name='Date', length=7150, freq=None)

# %%
shell.plot.line(y="Close", use_index=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
shell
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1996-08-29 00:00:00+01:00  3645.669678  3666.394889  3625.814378  3645.669678
# 1996-08-30 00:00:00+01:00  3586.582520  3614.415663  3580.673638  3586.582520
# 1996-09-02 00:00:00+01:00  3632.231934  3631.512133  3600.469174  3632.231934
# 1996-09-03 00:00:00+01:00  3627.405518  3646.091057  3617.777537  3627.405518
# 1996-09-04 00:00:00+01:00  3694.797119  3709.193498  3680.400374  3694.797119
# ...                                ...          ...          ...          ...
# 2024-08-23 00:00:00+01:00  2715.000000  2722.500000  2707.500000  2720.000000
# 2024-08-27 00:00:00+01:00  2755.000000  2761.729980  2721.500000  2725.000000
# 2024-08-28 00:00:00+01:00  2720.000000  2722.500000  2680.500000  2696.000000
# 2024-08-29 00:00:00+01:00  2691.000000  2718.761963  2670.500000  2711.000000
# 2024-08-30 00:00:00+01:00  2726.000000  2729.500000  2669.000000  2681.000000
#
# ...

# %%
shell['Dividends'].value_counts()
# Out:
# 0.0000     7073
# 15.6400       2
# 34.4000       2
# 17.1300       1
# 30.9200       1
#            ...
# 27.9200       1
# 26.7400       1
# 23.0435       1
# 25.7700       1
# 31.2000       1
# Name: Dividends, Length: 76, dtype: int64

# %%
BDEV = yf.Ticker("BDEV.L")

# %%
MKS.splits
# Out:
# Date
# 2002-03-19 00:00:00+00:00    0.809524
# Name: Stock Splits, dtype: float64

# %%
BDEV = BDEV.history(period="max")

# %%
BDEV
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1988-07-01 00:00:00+01:00   39.693962   39.693962   39.693962   39.693962
# 1988-07-04 00:00:00+01:00   38.649395   38.649395   38.649395   38.649395
# 1988-07-05 00:00:00+01:00   38.231594   38.231594   38.231594   38.231594
# 1988-07-06 00:00:00+01:00   37.813725   37.813725   37.813725   37.813725
# 1988-07-07 00:00:00+01:00   37.813725   37.813725   37.813725   37.813725
# ...                               ...         ...         ...         ...
# 2024-10-18 00:00:00+01:00  488.200012  494.000000  480.299988  488.100006
# 2024-10-21 00:00:00+01:00  500.000000  507.399994  481.399994  481.399994
# 2024-10-22 00:00:00+01:00  478.299988  482.299988  473.299988  473.399994
# 2024-10-23 00:00:00+01:00  475.000000  491.459991  475.000000  485.299988
# 2024-10-24 00:00:00+01:00  483.700012  486.500000  479.406006  481.200012
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
BDEV = yf.Ticker("BDEV.L")
BDEV = BDEV.history(period="max", auto_adjust=False)
BDEV
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1988-07-01 00:00:00+01:00  118.062302  118.062302  118.062302  118.062302
# 1988-07-04 00:00:00+01:00  114.955399  114.955399  114.955399  114.955399
# 1988-07-05 00:00:00+01:00  113.712700  113.712700  113.712700  113.712700
# 1988-07-06 00:00:00+01:00  112.469902  112.469902  112.469902  112.469902
# 1988-07-07 00:00:00+01:00  112.469902  112.469902  112.469902  112.469902
# ...                               ...         ...         ...         ...
# 2024-10-18 00:00:00+01:00  488.200012  494.000000  480.299988  488.100006
# 2024-10-21 00:00:00+01:00  500.000000  507.399994  481.399994  481.399994
# 2024-10-22 00:00:00+01:00  478.299988  482.299988  473.299988  473.399994
# 2024-10-23 00:00:00+01:00  475.000000  491.459991  475.000000  485.299988
# 2024-10-24 00:00:00+01:00  483.700012  486.500000  479.406006  481.200012
#
#                             Adj Close   Volume  Dividends  Stock Splits
# ...

# %%
BDEV.to_csv("MKS.csv")

# %%
KETL.to_pickle("KETL.pkl")

# %%
SVT_reloaded = pd.read_pickle("SVT.pkl")

# %%
SVT_reloaded
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1989-12-11 00:00:00+00:00    76.455757    76.455757    76.455757    76.455757
# 1989-12-12 00:00:00+00:00    86.331322    86.331322    86.331322    86.331322
# 1989-12-13 00:00:00+00:00    86.331322    86.331322    86.331322    86.331322
# 1989-12-14 00:00:00+00:00    86.012733    86.012733    86.012733    86.012733
# 1989-12-15 00:00:00+00:00    85.694145    85.694145    85.694145    85.694145
# ...                                ...          ...          ...          ...
# 2024-09-24 00:00:00+01:00  2639.000000  2645.000000  2615.399902  2644.000000
# 2024-09-25 00:00:00+01:00  2621.000000  2646.000000  2613.000000  2646.000000
# 2024-09-26 00:00:00+01:00  2664.000000  2671.000000  2628.000000  2638.000000
# 2024-09-27 00:00:00+01:00  2641.000000  2678.257080  2641.000000  2661.000000
# 2024-09-30 00:00:00+01:00  2647.000000  2659.000000  2617.000000  2642.000000
#
# ...

# %%
KETL = yf.Ticker("KETL.L")

# %%
KETL_historical = KETL.history(start="2020-06-02", end="2020-06-07")
KETL_historical
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-06-02 00:00:00+01:00  163.341867  171.377935  162.468381  169.456268
# 2020-06-03 00:00:00+01:00  168.582796  172.950226  161.594908  172.950226
# 2020-06-04 00:00:00+01:00  172.775555  173.299639  166.601748  169.805695
# 2020-06-05 00:00:00+01:00  170.679171  172.950240  169.044010  169.980392
#
#                             Volume  Dividends  Stock Splits
# Date
# 2020-06-02 00:00:00+01:00   346698        0.0           0.0
# 2020-06-03 00:00:00+01:00  1157351        0.0           0.0
# 2020-06-04 00:00:00+01:00   315603        0.0           0.0
# 2020-06-05 00:00:00+01:00   404057        0.0           0.0

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
#url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=MKS&interval=5min&apikey=KGJRZMF6U5ZZIEPV'

url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MKS.LON&outputsize=full&apikey=KGJRZMF6U5ZZIEPV'
r = requests.get(url)
data = r.json()

#print(data)

# %%
import pandas as pd
# Load the data from the API
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MKS.LON&outputsize=full&apikey=KGJRZMF6U5ZZIEPV"
request = requests.get(url)
json_data = request.json()
#print(json_data)
# Convert to DataFrame
pricing_df = pd.DataFrame.from_dict(json_data)
"""pricing_df.columns = ["Open", "High", "Low", "Close", "Volume"]
pricing_df.index = pd.to_datetime(pricing_df.index)
pricing_df.index.rename("Date", inplace = True)
pricing_df.sort_index(ascending=True, inplace=True)

pricing_df = pricing_df.astype(float)

pricing_df.tail(15)
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 # Load the data from the API
#       3 url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=MKS.LON&outputsize=full&apikey=KGJRZMF6U5ZZIEPV"
# ----> 4 request = requests.get(url)
#       5 json_data = request.json()
#       6 #print(json_data)
#       7 # Convert to DataFrame
#
# NameError: name 'requests' is not defined

# %%
pricing_df
# Out:
#                                                            Meta Data  \
# 1. Information     Daily Prices (open, high, low, close) and Volumes
# 2. Symbol                                                    MKS.LON
# 3. Last Refreshed                                         2024-10-22
# 4. Output Size                                             Full size
# 5. Time Zone                                              US/Eastern
# ...                                                              ...
# 2005-01-10                                                       NaN
# 2005-01-07                                                       NaN
# 2005-01-06                                                       NaN
# 2005-01-05                                                       NaN
# 2005-01-04                                                       NaN
#
#                                                  Time Series (Daily)
# 1. Information                                                   NaN
# ...

# %%
pip install alpha_vantage pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from alpha_vantage.timeseries import TimeSeries
# Create an API object
ts = TimeSeries(output_format='pandas', key='KGJRZMF6U5ZZIEPV')
print(type(ts))
# Get daily OHLC data for NVDA
data, meta_data = ts.get_daily(symbol="BLND.LON", outputsize='full')
print(data)
# Out:
# <class 'alpha_vantage.timeseries.TimeSeries'>
#              1. open   2. high    3. low  4. close  5. volume
# date
# 2024-10-25  418.6000  419.8000  414.8000  415.6000  1758057.0
# 2024-10-24  419.4000  422.6000  417.8000  418.8000  1289017.0
# 2024-10-23  421.4000  423.2000  414.4000  420.0000  2323142.0
# 2024-10-22  425.0000  426.4000  418.8000  421.4000  4141313.0
# 2024-10-21  432.8000  436.0000  428.2000  428.6000  1478519.0
# ...              ...       ...       ...       ...        ...
# 2005-01-07  861.4975  877.4974  856.4976  873.4974  2772715.0
# 2005-01-06  859.9974  863.9974  846.4976  856.4976  4791102.0
# 2005-01-05  874.9975  874.9975  862.2975  863.9974  6933572.0
# 2005-01-04  894.9974  894.9974  871.9975  874.4974  4991026.0
# 2005-01-03  895.9973  895.9973  895.9973  895.9973        0.0
#
# [5015 rows x 5 columns]

# %%
print(meta_data)
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'BLND.LON', '3. Last Refreshed': '2024-10-25', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}

# %%
df18 = data.loc["2018-01-01":].copy()
# Out:
# /var/folders/5b/ch8vy6rj4ngf5d3zw95w9l200000gn/T/ipykernel_71225/2587412816.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df18 = data.loc["2018-01-01":].copy()

# %%
df18
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2024-10-25    418.6    419.8   414.8     415.6  1758057.0
# 2024-10-24    419.4    422.6   417.8     418.8  1289017.0
# 2024-10-23    421.4    423.2   414.4     420.0  2323142.0
# 2024-10-22    425.0    426.4   418.8     421.4  4141313.0
# 2024-10-21    432.8    436.0   428.2     428.6  1478519.0
# ...             ...      ...     ...       ...        ...
# 2018-01-08    675.6    685.2   675.6     680.6  4334152.0
# 2018-01-05    663.2    675.4   663.2     674.8  3876711.0
# 2018-01-04    678.6    679.0   662.2     665.2  5992264.0
# 2018-01-03    686.8    688.2   681.0     686.0  3584812.0
# 2018-01-02    681.0    691.4   681.0     684.2  3119191.0
#
# [1723 rows x 5 columns]

# %%
df18.columns = ["Open", "High", "Low", "Close", "Volume"]

# %%
df18
# Out:
#              Open   High    Low  Close     Volume
# date
# 2024-10-25  418.6  419.8  414.8  415.6  1758057.0
# 2024-10-24  419.4  422.6  417.8  418.8  1289017.0
# 2024-10-23  421.4  423.2  414.4  420.0  2323142.0
# 2024-10-22  425.0  426.4  418.8  421.4  4141313.0
# 2024-10-21  432.8  436.0  428.2  428.6  1478519.0
# ...           ...    ...    ...    ...        ...
# 2018-01-08  675.6  685.2  675.6  680.6  4334152.0
# 2018-01-05  663.2  675.4  663.2  674.8  3876711.0
# 2018-01-04  678.6  679.0  662.2  665.2  5992264.0
# 2018-01-03  686.8  688.2  681.0  686.0  3584812.0
# 2018-01-02  681.0  691.4  681.0  684.2  3119191.0
#
# [1723 rows x 5 columns]

# %%
df18.to_pickle("01-Data/BLND.pkl")

# %%
BLND_reloaded = pd.read_pickle("01-Data/BLND.pkl")

# %%
BLND_reloaded.sort_index(inplace=True)
BLND_reloaded
# Out:
#              Open   High    Low  Close     Volume
# date
# 2018-01-02  681.0  691.4  681.0  684.2  3119191.0
# 2018-01-03  686.8  688.2  681.0  686.0  3584812.0
# 2018-01-04  678.6  679.0  662.2  665.2  5992264.0
# 2018-01-05  663.2  675.4  663.2  674.8  3876711.0
# 2018-01-08  675.6  685.2  675.6  680.6  4334152.0
# ...           ...    ...    ...    ...        ...
# 2024-10-21  432.8  436.0  428.2  428.6  1478519.0
# 2024-10-22  425.0  426.4  418.8  421.4  4141313.0
# 2024-10-23  421.4  423.2  414.4  420.0  2323142.0
# 2024-10-24  419.4  422.6  417.8  418.8  1289017.0
# 2024-10-25  418.6  419.8  414.8  415.6  1758057.0
#
# [1723 rows x 5 columns]

# %%
# find max from three numbers 
print( max(1, 2, 3))
# Out:
# 3

# %%
df = BLND_reloaded

# Define the target date
target_date = pd.to_datetime('2022-04-23')

# Check if the date exists in the index
if target_date in df.index:
    # Get the index location
    index_location = df.index.get_loc(target_date)
    print(f"Date {target_date} found at index location: {index_location}")
else:
    # Find the closest prior date
    closest_date = df.index[df.index < target_date].max()
    if pd.isnull(closest_date):
        print("No previous date found in the dataset.")
    else:
        # Get the index location of the closest prior date
        index_location = df.index.get_loc(closest_date)
        print(f"Date {target_date} not found. Closest prior date is {closest_date} at index location: {index_location}")
# Out:
# Date 2022-04-23 00:00:00 not found. Closest prior date is 2022-04-22 00:00:00 at index location: 1089

# %%
# Define how many records we want to check before and after
records_before = 35
records_after = 15

# Check if there are enough records before and after
has_records_before = index_location >= records_before
has_records_after = index_location + records_after < len(df)

# Print the appropriate message based on the conditions
if has_records_before and has_records_after:
    print("There are at least 35 records before and 15 records after the given date.")
else:
    print("There are NOT enough records to satisfy both conditions.")
# Out:
# There are at least 35 records before and 15 records after the given date.

# %%
# Calculate the start and end positions for slicing
start_pos = index_location - records_before
end_pos = index_location + records_after + 1  # +1 to include the row at `index_location + records_after`

# Ensure start_pos is not less than 0 (in case it's close to the start of the DataFrame)
if start_pos < 0:
    start_pos = 0

# Slice the DataFrame
trimmed_df = df.iloc[start_pos:end_pos]

# Print the result or inspect
print("Trimmed DataFrame:")
print(trimmed_df)
#df =trimmed_df.copy()
# Out:
# Trimmed DataFrame:
#              Open     High      Low  Close     Volume
# date
# 2022-03-02  510.2  519.800  506.000  517.2  3521277.0
# 2022-03-03  515.6  519.600  496.000  496.0  1761884.0
# 2022-03-04  496.0  496.000  469.100  472.9  2368679.0
# 2022-03-07  459.3  469.100  441.700  463.1  2866452.0
# 2022-03-08  455.0  479.400  453.800  468.5  2508241.0
# 2022-03-09  482.6  495.700  479.300  494.7  1925761.0
# 2022-03-10  496.4  502.200  488.011  494.7  1507991.0
# 2022-03-11  497.6  507.200  494.200  499.4  1850231.0
# 2022-03-14  503.2  512.223  501.800  506.8  1370710.0
# 2022-03-15  502.4  507.000  499.000  502.8  1333113.0
# 2022-03-16  509.8  526.000  509.800  520.8  2709538.0
# 2022-03-17  524.0  528.000  516.800  521.8  1522891.0
# 2022-03-18  521.8  522.800  509.800  519.8  3439756.0
# 2022-03-21  518.2  520.800  511.800  514.0  7785222.0
# 2022-03-22  514.2  524.800  513.600  521.6  1298192.0
# 2022-03-23  521.6  523.000  509.400  510.0  1276968.0
# ...

# %%
# Copy the date index values into a new column called 'date'
trimmed_df['date'] = trimmed_df.index.copy()


# Add a new column 'labels' with default values, such as None or any placeholder you like
df['labels'] = 0

# To inspect the DataFrame with the new column
print(trimmed_df.head())
# Out:
#              Open   High    Low  Close     Volume       date
# date
# 2022-03-02  510.2  519.8  506.0  517.2  3521277.0 2022-03-02
# 2022-03-03  515.6  519.6  496.0  496.0  1761884.0 2022-03-03
# 2022-03-04  496.0  496.0  469.1  472.9  2368679.0 2022-03-04
# 2022-03-07  459.3  469.1  441.7  463.1  2866452.0 2022-03-07
# 2022-03-08  455.0  479.4  453.8  468.5  2508241.0 2022-03-08
# /var/folders/5b/ch8vy6rj4ngf5d3zw95w9l200000gn/T/ipykernel_71225/2911326769.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trimmed_df['date'] = trimmed_df.index.copy()

# %%
# Re-index the trimmed DataFrame to ensure indices are continuous
trimmed_df = trimmed_df.reset_index(drop=True)

# Initialize the 'labels' column in the trimmed DataFrame with 0 as the default value
trimmed_df['labels'] = 0

# Prepare an empty list to capture the number of days it took for each record to meet the first condition
days_to_hit_high_threshold = []

# Loop through each row until reaching `len(trimmed_df) - 15` to stay within bounds
for i in range(len(trimmed_df) - 15):
    # Define the start record as the current row
    start_value = (trimmed_df.iloc[i]['High'] + trimmed_df.iloc[i]['Low']) / 2
    
    # Set thresholds for high and low based on start_value
    high_threshold = start_value + 10
    low_threshold = start_value - 5
    
    # Initialize flags for conditions
    high_condition_met = False
    low_condition_met = False
    
    # Check the next 15 records for each condition
    for j in range(1, 16):
        # Ensure `i + j` does not exceed the DataFrame length
        if i + j >= len(trimmed_df):
            break
        
        # Access the row j days after the current record
        current_high = trimmed_df.iloc[i + j]['high']
        current_low = trimmed_df.iloc[i + j]['low']
        
        # Check if high threshold is met and capture the days taken to meet it
        if not high_condition_met and current_high > high_threshold:
            high_condition_met = True
            days_to_hit_high_threshold.append(j)  # Save the days it took to reach the threshold
        
        # Check if low threshold is met
        if not low_condition_met and current_low < low_threshold:
            low_condition_met = True
        
        # If both conditions are met, we can stop checking further for this record
        if high_condition_met and low_condition_met:
            break
    
    # If both conditions are met, label the current record with a 1
    if high_condition_met and low_condition_met:
        trimmed_df.at[i, 'labels'] = 1

# Print the resulting DataFrame and the days to hit the high threshold
print(trimmed_df)
print("Days to hit high threshold for each record:", days_to_hit_high_threshold)
# Out:
#      Open     High      Low  Close     Volume       date  labels
# 0   510.2  519.800  506.000  517.2  3521277.0 2022-03-02       1
# 1   515.6  519.600  496.000  496.0  1761884.0 2022-03-03       1
# 2   496.0  496.000  469.100  472.9  2368679.0 2022-03-04       1
# 3   459.3  469.100  441.700  463.1  2866452.0 2022-03-07       0
# 4   455.0  479.400  453.800  468.5  2508241.0 2022-03-08       0
# 5   482.6  495.700  479.300  494.7  1925761.0 2022-03-09       0
# 6   496.4  502.200  488.011  494.7  1507991.0 2022-03-10       0
# 7   497.6  507.200  494.200  499.4  1850231.0 2022-03-11       0
# 8   503.2  512.223  501.800  506.8  1370710.0 2022-03-14       1
# 9   502.4  507.000  499.000  502.8  1333113.0 2022-03-15       0
# 10  509.8  526.000  509.800  520.8  2709538.0 2022-03-16       1
# 11  524.0  528.000  516.800  521.8  1522891.0 2022-03-17       1
# 12  521.8  522.800  509.800  519.8  3439756.0 2022-03-18       1
# ...

# %%
import pandas as pd

# %%
SN_df = pd.read_pickle('data/SN.pkl')

# %%
SN_df
# Out:
#               Open    High       Low     Close     Volume
# date
# 2024-10-25  1122.5  1125.5  1071.000  1088.000  3671923.0
# 2024-10-24  1125.5  1134.0  1122.000  1122.386  5963551.0
# 2024-10-23  1127.0  1131.0  1114.785  1123.000  1923992.0
# 2024-10-22  1123.5  1132.0  1118.500  1129.000  1866592.0
# 2024-10-21  1125.0  1136.0  1123.500  1126.000  1533292.0
# ...            ...     ...       ...       ...        ...
# 2018-01-08  1286.5  1290.0  1274.500  1285.000  2092807.0
# 2018-01-05  1259.0  1287.0  1257.500  1285.500  2508938.0
# 2018-01-04  1266.5  1266.5  1254.000  1257.500  2695234.0
# 2018-01-03  1267.5  1273.0  1258.000  1265.000  1783425.0
# 2018-01-02  1280.5  1285.5  1262.000  1263.000  2326721.0
#
# [1723 rows x 5 columns]

# %%
SN_df.to_csv('SN.csv')

# %%
SN = pd.read_pickle("models/1/SlicedSN.pkl")

# %%
SN
# Out:
#         open    high     low   close   volume        date  labels
# 0     1861.5  1890.0  1856.5  1884.0  4152700  2019-10-04       0
# 1     1876.0  1910.0  1871.0  1909.5  1786955  2019-10-07       0
# 2     1909.5  1943.5  1909.0  1912.0  1678805  2019-10-08       0
# 3     1903.5  1926.0  1899.5  1906.5  1787699  2019-10-09       0
# 4     1902.5  1908.0  1880.5  1886.0  1484068  2019-10-10       0
# ...      ...     ...     ...     ...      ...         ...     ...
# 1266  1096.5  1099.0  1085.0  1093.0  2496430  2024-10-10       0
# 1267  1089.5  1097.0  1084.5  1087.0  2197544  2024-10-11       0
# 1268  1085.5  1090.0  1080.0  1089.0  2065288  2024-10-14       0
# 1269  1095.0  1102.0  1059.5  1084.5  4839427  2024-10-15       0
# 1270  1092.0  1112.5  1088.5  1108.5  2552575  2024-10-16       0
#
# [1271 rows x 7 columns]

# %%
SN['labels'].value_counts()
# Out:
# labels
# 0    948
# 1    323
# Name: count, dtype: int64

# %%
SN.set_index('date')
# Out:
#               open    high     low   close   volume  labels
# date
# 2019-10-04  1861.5  1890.0  1856.5  1884.0  4152700       0
# 2019-10-07  1876.0  1910.0  1871.0  1909.5  1786955       0
# 2019-10-08  1909.5  1943.5  1909.0  1912.0  1678805       0
# 2019-10-09  1903.5  1926.0  1899.5  1906.5  1787699       0
# 2019-10-10  1902.5  1908.0  1880.5  1886.0  1484068       0
# ...            ...     ...     ...     ...      ...     ...
# 2024-10-10  1096.5  1099.0  1085.0  1093.0  2496430       0
# 2024-10-11  1089.5  1097.0  1084.5  1087.0  2197544       0
# 2024-10-14  1085.5  1090.0  1080.0  1089.0  2065288       0
# 2024-10-15  1095.0  1102.0  1059.5  1084.5  4839427       0
# 2024-10-16  1092.0  1112.5  1088.5  1108.5  2552575       0
#
# [1271 rows x 6 columns]

# %%
SN.dtypes
# Out:
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# date       object
# labels      int64
# dtype: object

# %%
EDV = pd.read_pickle("models/1/screening/Screened_EDV.pkl")

# %%
EDV
# Out:
#               open       high      low   close  volume  labels
# date
# 2023-03-02  1754.0  1778.0000  1749.00  1762.0  302103       0
# 2023-03-03  1765.0  1792.0000  1761.00  1775.0  355866       0
# 2023-03-06  1775.0  1777.0000  1743.00  1743.0  515991       0
# 2023-03-07  1746.0  1746.0000  1682.00  1685.0  334679       0
# 2023-03-08  1676.0  1700.0000  1663.00  1691.0  346782       0
# ...            ...        ...      ...     ...     ...     ...
# 2024-09-26  1911.0  1928.3210  1870.00  1877.0  465980       0
# 2024-09-27  1869.0  1877.0000  1813.00  1826.0  566493       0
# 2024-09-30  1803.0  1835.1899  1758.00  1771.0  489685       0
# 2024-10-01  1787.0  1822.4611  1765.96  1797.0  244720       0
# 2024-10-02  1790.0  1813.0000  1778.00  1787.0  357447       0
#
# [401 rows x 6 columns]
