# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
# Out:
# 2024-12-04 17:56:39.663064: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-04 17:56:39.671315: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733334999.678755   46604 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733334999.681134   46604 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-04 17:56:39.690252: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def calculate_ema(series, length):
    """
    Calculate Exponential Moving Average (EMA) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which EMA is to be calculated (e.g., 'close' prices).
    - length (int): The period length for EMA (e.g., 10 for EMA_10).
    
    Returns:
    - pd.Series: EMA values.
    """
    alpha = 2 / (length + 1)
    ema = series.ewm(alpha=alpha, adjust=False).mean()
    return ema

# Example usage
#df['EMA_10'] = calculate_ema(df['close'], length=10)

def calculate_rsi(series, length=14):
    """
    Calculate Relative Strength Index (RSI) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which RSI is to be calculated (e.g., 'close' prices).
    - length (int): The period length for RSI (default is 14).
    
    Returns:
    - pd.Series: RSI values.
    """
    delta = series.diff(1)
    gain = delta.where(delta > 0, 0)  # Positive changes
    loss = -delta.where(delta < 0, 0)  # Negative changes (converted to positive)
    
    avg_gain = gain.rolling(window=length, min_periods=length).mean()
    avg_loss = loss.rolling(window=length, min_periods=length).mean()
    
    # Use exponentially weighted moving average for smoothing (optional, common in practice)
    avg_gain = avg_gain.ewm(com=length - 1, adjust=False).mean()
    avg_loss = avg_loss.ewm(com=length - 1, adjust=False).mean()
    
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    
    return rsi

# Example usage
#df['RSI'] = calculate_rsi(df['close'], length=14)


def calculate_macd(series, fast_length=12, slow_length=26, signal_length=9):
    """
    Calculate MACD (Moving Average Convergence Divergence) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which MACD is to be calculated (e.g., 'close' prices).
    - fast_length (int): The period for the fast EMA (default is 12).
    - slow_length (int): The period for the slow EMA (default is 26).
    - signal_length (int): The period for the signal line EMA (default is 9).
    
    Returns:
    - pd.DataFrame: DataFrame containing MACD line, signal line, and histogram.
    """
    fast_ema = series.ewm(span=fast_length, adjust=False).mean()
    slow_ema = series.ewm(span=slow_length, adjust=False).mean()
    macd_line = fast_ema - slow_ema
    signal_line = macd_line.ewm(span=signal_length, adjust=False).mean()
    histogram = macd_line - signal_line
    
    return pd.DataFrame({
        'MACD': macd_line,
        'Signal': signal_line,
        'Histogram': histogram
    })

# Example usage
#macd = calculate_macd(df['close'])
#df['MACD'] = macd['MACD']
#df['Signal'] = macd['Signal']
#df['Histogram'] = macd['Histogram']

# %%
df = pd.read_pickle("Screened_NWG.pkl")

# %%
def create_sequences_multistep(data, target_feature, window_size, future_steps):
    X, y = [], []
    for i in range(len(data) - window_size - future_steps + 1):
        X.append(data[i:(i + window_size)])
        y.append(data[(i + window_size):(i + window_size + future_steps), target_feature])  # Predict `future_steps`
    return np.array(X), np.array(y)

# Add indicators to the DataFrame
df['SMA_10'] = df['high'].rolling(window=10).mean()
df['EMA_10'] = calculate_ema(df['high'], length=10)  # Exponential Moving Average (10 periods)
df['RSI'] = calculate_rsi(df['high'], length=14)     # Relative Strength Index (14 periods)
macd = calculate_macd(df['high'])
df['MACD'] = macd['MACD']
df['Signal'] = macd['Signal']
df['Histogram'] = macd['Histogram']

# Prepare the dataset
df2 = df.dropna()  # Drop rows with NaN values after adding indicators

# Select features
features = df2[[ 'high',  'SMA_10', 'EMA_10', 'RSI', 'MACD', 'Signal', 'Histogram']].values

# Index of the target feature
target_feature_index = 0  # Index of "high" in the features array

# Normalize the data
from sklearn.preprocessing import MinMaxScaler
feature_scaler = MinMaxScaler()
features_normalized = feature_scaler.fit_transform(features)

# Scaler for target feature (high)
target_scaler = MinMaxScaler()
high_normalized = target_scaler.fit_transform(features[:, target_feature_index].reshape(-1, 1))  # Only scale "high"

# Create sequences
window_size = 15
future_steps = 5
X, y = create_sequences_multistep(features_normalized, target_feature_index, window_size, future_steps)

# Adjust X shape for the GRU model (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], X.shape[2]))  # Shape (num_samples, window_size, num_features)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
from keras.layers import GRU, Dropout, Dense
from keras.models import Sequential

gru_model = Sequential()

# First GRU layer with dropout
gru_model.add(GRU(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
gru_model.add(Dropout(0.2))

# Second GRU layer with dropout
gru_model.add(GRU(50, return_sequences=True))
gru_model.add(Dropout(0.2))

# Third GRU layer with dropout
gru_model.add(GRU(50, return_sequences=True))
gru_model.add(Dropout(0.2))

# Fourth GRU layer with dropout
gru_model.add(GRU(50))
gru_model.add(Dropout(0.2))

# Output layer
gru_model.add(Dense(future_steps))  # Output layer for `future_steps` predictions

gru_model.compile(optimizer='adam', loss='mean_squared_error',  metrics=['accuracy'])

gru_model.summary()
# Out:
# I0000 00:00:1733335372.172791   46604 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5249 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050, pci bus id: 0000:81:00.0, compute capability: 8.6
# /home/dave/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 15, 50)         │         8,850 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 15, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, 15, 50)         │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, 50)             │        15,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           255 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,005 (214.86 KB)
#  Trainable params: 55,005 (214.86 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#gru_model.fit(X_train, y_train,validation_data=(X_test, y_test), epochs=30, batch_size=24, verbose=1)

history = gru_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=16,
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/50
# I0000 00:00:1733335393.246207   46947 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2144 - loss: 0.0621 - val_accuracy: 0.3973 - val_loss: 0.0113
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1995 - loss: 0.0097 - val_accuracy: 0.1295 - val_loss: 0.0082
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2225 - loss: 0.0070 - val_accuracy: 0.1250 - val_loss: 0.0028
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2184 - loss: 0.0061 - val_accuracy: 0.1116 - val_loss: 0.0033
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2101 - loss: 0.0058 - val_accuracy: 0.3973 - val_loss: 0.0094
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1792 - loss: 0.0054 - val_accuracy: 0.3125 - val_loss: 0.0048
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1748 - loss: 0.0043 - val_accuracy: 0.2188 - val_loss: 0.0033
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1736 - loss: 0.0045 - val_accuracy: 0.3973 - val_loss: 0.0059
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2328 - loss: 0.0042 - val_accuracy: 0.1741 - val_loss: 0.0034
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2187 - loss: 0.0045 - val_accuracy: 0.1295 - val_loss: 0.0081
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1917 - loss: 0.0034 - val_accuracy: 0.3973 - val_loss: 0.0023
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2334 - loss: 0.0032 - val_accuracy: 0.1250 - val_loss: 0.0024
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1695 - loss: 0.0038 - val_accuracy: 0.1696 - val_loss: 0.0021
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2166 - loss: 0.0035 - val_accuracy: 0.1116 - val_loss: 0.0043
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1826 - loss: 0.0028 - val_accuracy: 0.1473 - val_loss: 0.0065
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1820 - loss: 0.0028 - val_accuracy: 0.2321 - val_loss: 0.0032
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2123 - loss: 0.0024 - val_accuracy: 0.1250 - val_loss: 0.0018
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2238 - loss: 0.0027 - val_accuracy: 0.2366 - val_loss: 0.0016
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2157 - loss: 0.0029 - val_accuracy: 0.4241 - val_loss: 0.0030
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2048 - loss: 0.0024 - val_accuracy: 0.1607 - val_loss: 0.0024
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2110 - loss: 0.0023 - val_accuracy: 0.2009 - val_loss: 0.0033
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2133 - loss: 0.0023 - val_accuracy: 0.4241 - val_loss: 0.0024
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1970 - loss: 0.0021 - val_accuracy: 0.1830 - val_loss: 0.0034
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1932 - loss: 0.0025 - val_accuracy: 0.2277 - val_loss: 0.0018
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.1996 - loss: 0.0022 - val_accuracy: 0.1295 - val_loss: 0.0019
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2191 - loss: 0.0021 - val_accuracy: 0.3259 - val_loss: 0.0024
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1937 - loss: 0.0021 - val_accuracy: 0.1607 - val_loss: 0.0053
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1947 - loss: 0.0021 - val_accuracy: 0.2545 - val_loss: 0.0022

# %%
import matplotlib.pyplot as plt

# Make predictions
predictions = gru_model.predict(X_test)

# Visualize predictions for a single sequence
for i in range(5):  # Plot for each step (e.g., 1st day, 2nd day, ..., 5th day)
    plt.figure(figsize=(10, 5))
    plt.plot(y_test[:, i], label=f"Actual {i+1} days ahead")
    plt.plot(predictions[:, i], label=f"Predicted {i+1} days ahead")
    plt.legend()
    plt.title(f"Prediction for {i+1} days ahead")
    plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Evaluate the model
loss, accuracy = gru_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Visualize results
#import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2295 - loss: 0.0011
# Test Accuracy: 0.24

# %%
# Provide the last 15 days of data from X_test
input_sequence = X_test[-1]  # Shape: (window_size, num_features)
input_sequence = input_sequence.reshape(1, input_sequence.shape[0], input_sequence.shape[1])  # Reshape for batch size

# Predict the next 5 days
next_5_days = gru_model.predict(input_sequence)  # Shape: (1, 5)
print("Predicted next 5 days:", next_5_days[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Predicted next 5 days: [0.8794675  0.87078965 0.87316805 0.85796255 0.8651663 ]

# %%
plt.plot(range(15), X_test[-1][:, 0], label="Input (last 15 days)")  # Assuming the first feature is the target
plt.plot(range(15, 20), y_test[-1], label="Actual next 5 days")  # Actual values for the next 5 days
plt.plot(range(15, 20), next_5_days[0], label="Predicted next 5 days")  # Predicted values
plt.legend()
plt.show()

# %%
from keras.layers import LSTM, Dropout, SimpleRNN

lstm_model = Sequential()

# First LSTM layer with dropout
lstm_model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
lstm_model.add(Dropout(0.2))

# Second LSTM layer with dropout
lstm_model.add(LSTM(50, return_sequences=True))
lstm_model.add(Dropout(0.2))

# Third LSTM layer with dropout
lstm_model.add(LSTM(50, return_sequences=True))
lstm_model.add(Dropout(0.2))

# Fourth LSTM layer with dropout
lstm_model.add(LSTM(50))
lstm_model.add(Dropout(0.2))

# Output layer
lstm_model.add(Dense(1))

lstm_model.compile(optimizer='adam', loss='mean_squared_error')

lstm_model.summary()
# Out:
# /home/dave/tf/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 15, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 15, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 15, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 15, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,051 (277.54 KB)
#  Trainable params: 71,051 (277.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm_model.fit(X_train, y_train, epochs=30, batch_size=24, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 lstm_model.fit(X_train, y_train,validation_data=(X_test, y_test), epochs=30, batch_size=24, verbose=1)
#
# NameError: name 'lstm_model' is not defined

# %%
import matplotlib.pyplot as plt

# Make predictions
predicted_lstm = lstm_model.predict(X_test)

# Inverse transform the predicted and actual values
predicted_lstm = scaler.inverse_transform(predicted_lstm)
y_test_actual = scaler.inverse_transform(y_test)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual')
plt.plot(predicted_lstm, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
