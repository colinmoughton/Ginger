# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf
# Out:
# 2024-12-06 10:27:38.932232: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-06 10:27:38.941591: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733480858.950693  125071 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733480858.953479  125071 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-06 10:27:38.964501: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def calculate_ema(series, length):
    """
    Calculate Exponential Moving Average (EMA) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which EMA is to be calculated (e.g., 'close' prices).
    - length (int): The period length for EMA (e.g., 10 for EMA_10).
    
    Returns:
    - pd.Series: EMA values.
    """
    alpha = 2 / (length + 1)
    ema = series.ewm(alpha=alpha, adjust=False).mean()
    return ema

# Example usage
#df['EMA_10'] = calculate_ema(df['close'], length=10)

def calculate_rsi(series, length=14):
    """
    Calculate Relative Strength Index (RSI) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which RSI is to be calculated (e.g., 'close' prices).
    - length (int): The period length for RSI (default is 14).
    
    Returns:
    - pd.Series: RSI values.
    """
    delta = series.diff(1)
    gain = delta.where(delta > 0, 0)  # Positive changes
    loss = -delta.where(delta < 0, 0)  # Negative changes (converted to positive)
    
    avg_gain = gain.rolling(window=length, min_periods=length).mean()
    avg_loss = loss.rolling(window=length, min_periods=length).mean()
    
    # Use exponentially weighted moving average for smoothing (optional, common in practice)
    avg_gain = avg_gain.ewm(com=length - 1, adjust=False).mean()
    avg_loss = avg_loss.ewm(com=length - 1, adjust=False).mean()
    
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    
    return rsi

# Example usage
#df['RSI'] = calculate_rsi(df['close'], length=14)


def calculate_macd(series, fast_length=12, slow_length=26, signal_length=9):
    """
    Calculate MACD (Moving Average Convergence Divergence) for a Pandas Series.
    
    Args:
    - series (pd.Series): The data for which MACD is to be calculated (e.g., 'close' prices).
    - fast_length (int): The period for the fast EMA (default is 12).
    - slow_length (int): The period for the slow EMA (default is 26).
    - signal_length (int): The period for the signal line EMA (default is 9).
    
    Returns:
    - pd.DataFrame: DataFrame containing MACD line, signal line, and histogram.
    """
    fast_ema = series.ewm(span=fast_length, adjust=False).mean()
    slow_ema = series.ewm(span=slow_length, adjust=False).mean()
    macd_line = fast_ema - slow_ema
    signal_line = macd_line.ewm(span=signal_length, adjust=False).mean()
    histogram = macd_line - signal_line
    
    return pd.DataFrame({
        'MACD': macd_line,
        'Signal': signal_line,
        'Histogram': histogram
    })

# Example usage
#macd = calculate_macd(df['close'])
#df['MACD'] = macd['MACD']
#df['Signal'] = macd['Signal']
#df['Histogram'] = macd['Histogram']

# %%
# Inputs from Ginger
test_days=200
train_days=1000
trade_window=5
end_date = "2024-09-11"


df = pd.read_pickle("Screened_FRES.pkl")

# %%
def create_sequences_multifeature(data, target_feature, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:(i + window_size)])  # Collect the window of all features
        y.append(data[i + window_size, target_feature])  # Predict only the target feature (e.g., "high")
    return np.array(X), np.array(y)


# Add indicators to the DataFrame
df['SMA_10'] = df['high'].rolling(window=10).mean()
df['EMA_10'] = calculate_ema(df['high'], length=10)  # Exponential Moving Average (10 periods)
df['RSI'] = calculate_rsi(df['high'], length=14)     # Relative Strength Index (14 periods)
macd = calculate_macd(df['high'])
df['MACD'] = macd['MACD']
df['Signal'] = macd['Signal']
df['Histogram'] = macd['Histogram']
df['pct_change_high'] = df['high'].pct_change()
# Rolling standard deviation (volatility)
df['volatility'] = df['high'].rolling(window=5).std()
# Prepare the dataset
#features = df[["open", "high", "low", "close"]].values  # Shape (num_samples, 4)
# Detrended price
rolling_mean = df['high'].rolling(window=14).mean()
df['dpo'] = df['high'] - rolling_mean.shift(14 // 2)

# Prepare the dataset
#features = df[["open", "high", "low", "close"]].values  # Shape (num_samples, 4)

#df2=df.dropna()
df2 = df.iloc[100:-trade_window]

features = df2[[ 'high', 'pct_change_high']].values
#features = df2[[ 'high',  'SMA_10', 'EMA_10', 'RSI', 'MACD', 'Signal', 'Histogram']].values
#features = df2[['open', 'high', 'low', 'close', 'SMA_10', 'EMA_10', 'RSI', 'MACD', 'Signal', 'Histogram']].values


target_feature_index = 0  # Index of "high" in the features array

# Normalize the data (optional but recommended)
from sklearn.preprocessing import MinMaxScaler, StandardScaler
#scaler = MinMaxScaler()
#features_normalized = scaler.fit_transform(features)

# Scaler for input features (open, high, low, close)
feature_scaler = MinMaxScaler()
features_normalized = feature_scaler.fit_transform(features)

# Scaler for target feature (high)
target_scaler = MinMaxScaler()
high_normalized = target_scaler.fit_transform(features[:, target_feature_index].reshape(-1, 1))  # Only scale "high"


# Create sequences
window_size = 25
X, y = create_sequences_multifeature(features_normalized, target_feature_index, window_size)

# Adjust X shape for the GRU model (samples, timesteps, features)
X = X.reshape((X.shape[0], X.shape[1], X.shape[2]))  # Shape (num_samples, window_size, num_features)

# %%
#split = int(0.855 * len(X))


X_train, X_test = X[:train_days], X[train_days:]
y_train, y_test = y[:train_days], y[train_days:]

len(X_test)
# Out:
# 175

# %%
from keras.layers import Input, GRU, Dropout, Dense, Attention, GlobalAveragePooling1D
from keras.models import Model

# Input Layer
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

# GRU Layers with Dropout
gru_output = GRU(50, return_sequences=True)(input_layer)
gru_output = Dropout(0.2)(gru_output)

gru_output = GRU(50, return_sequences=True)(gru_output)
gru_output = Dropout(0.2)(gru_output)

gru_output = GRU(50, return_sequences=True)(gru_output)
gru_output = Dropout(0.2)(gru_output)

gru_output = GRU(50, return_sequences=True)(gru_output)
gru_output = Dropout(0.2)(gru_output)

# Attention Layer
attention_output = Attention()([gru_output, gru_output])

# Global Average Pooling Layer
pooled_output = GlobalAveragePooling1D()(attention_output)

# Fully Connected Output Layer
output_layer = Dense(1)(pooled_output)

# Define Model
attention_model = Model(inputs=input_layer, outputs=output_layer)
attention_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

attention_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 25, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_20 (GRU)        │ (None, 25, 50)    │      8,100 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 25, 50)    │          0 │ gru_20[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_21 (GRU)        │ (None, 25, 50)    │     15,300 │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 25, 50)    │          0 │ gru_21[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_22 (GRU)        │ (None, 25, 50)    │     15,300 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 25, 50)    │          0 │ gru_22[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_23 (GRU)        │ (None, 25, 50)    │     15,300 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 25, 50)    │          0 │ gru_23[0][0]      │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_5         │ (None, 25, 50)    │          0 │ dropout_23[0][0], │
# │ (Attention)         │                   │            │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 50)        │          0 │ attention_5[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         51 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 54,051 (211.14 KB)
#  Trainable params: 54,051 (211.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#gru_model.fit(X_train, y_train,validation_data=(X_test, y_test), epochs=30, batch_size=24, verbose=1)

history = attention_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=16,
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 6.4023e-04 - loss: 0.0447 - val_accuracy: 0.0057 - val_loss: 0.0028
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 6.6982e-04 - loss: 0.0072 - val_accuracy: 0.0057 - val_loss: 0.0024
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0018 - loss: 0.0070 - val_accuracy: 0.0057 - val_loss: 0.0025
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 4.7001e-05 - loss: 0.0059 - val_accuracy: 0.0057 - val_loss: 0.0027
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0037 - loss: 0.0065 - val_accuracy: 0.0057 - val_loss: 0.0024
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 4.7001e-05 - loss: 0.0059 - val_accuracy: 0.0057 - val_loss: 0.0037
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 6.3010e-05 - loss: 0.0055 - val_accuracy: 0.0057 - val_loss: 0.0021
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0015 - loss: 0.0061 - val_accuracy: 0.0057 - val_loss: 0.0032
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0010 - loss: 0.0053 - val_accuracy: 0.0057 - val_loss: 0.0019
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 2.9925e-04 - loss: 0.0047 - val_accuracy: 0.0057 - val_loss: 0.0018
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 7.9807e-04 - loss: 0.0046 - val_accuracy: 0.0057 - val_loss: 0.0192
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0022 - loss: 0.0080 - val_accuracy: 0.0057 - val_loss: 0.0018
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 9.8643e-04 - loss: 0.0049 - val_accuracy: 0.0057 - val_loss: 0.0019
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 7.0034e-04 - loss: 0.0039 - val_accuracy: 0.0057 - val_loss: 0.0020
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 5.8360e-04 - loss: 0.0039 - val_accuracy: 0.0057 - val_loss: 0.0015
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 5.0439e-04 - loss: 0.0033 - val_accuracy: 0.0057 - val_loss: 0.0030
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 5.5648e-04 - loss: 0.0038 - val_accuracy: 0.0057 - val_loss: 0.0028
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 2.5897e-04 - loss: 0.0031 - val_accuracy: 0.0057 - val_loss: 0.0013
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 4.5493e-04 - loss: 0.0029 - val_accuracy: 0.0057 - val_loss: 0.0017
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 6.6982e-04 - loss: 0.0027 - val_accuracy: 0.0057 - val_loss: 0.0030
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 6.4023e-04 - loss: 0.0023 - val_accuracy: 0.0057 - val_loss: 0.0013
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.2981e-04 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 9.3953e-04
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 2.5897e-04 - loss: 0.0022 - val_accuracy: 0.0057 - val_loss: 0.0012
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.4725e-04 - loss: 0.0025 - val_accuracy: 0.0057 - val_loss: 0.0014
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.2981e-04 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 0.0022
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 3.1250e-05 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 9.7412e-04
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 3.6296e-04 - loss: 0.0019 - val_accuracy: 0.0057 - val_loss: 5.0441e-04
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.4725e-04 - loss: 0.0018 - val_accuracy: 0.0057 - val_loss: 5.0267e-04
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.1268e-04 - loss: 0.0017 - val_accuracy: 0.0057 - val_loss: 5.3786e-04
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0037 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 0.0016
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0012 - loss: 0.0019 - val_accuracy: 0.0057 - val_loss: 8.3225e-04
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 2.5897e-04 - loss: 0.0014 - val_accuracy: 0.0057 - val_loss: 6.2541e-04
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0017 - loss: 0.0016 - val_accuracy: 0.0057 - val_loss: 0.0012
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 8.6911e-04 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 2.7355e-04
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 4.5493e-04 - loss: 0.0017 - val_accuracy: 0.0057 - val_loss: 0.0015
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 3.8515e-04 - loss: 0.0017 - val_accuracy: 0.0057 - val_loss: 9.5015e-04
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 5.3008e-04 - loss: 0.0021 - val_accuracy: 0.0057 - val_loss: 3.4859e-04
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0013 - loss: 0.0014 - val_accuracy: 0.0057 - val_loss: 5.3473e-04
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0037 - loss: 0.0016 - val_accuracy: 0.0057 - val_loss: 8.0902e-04
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 3.8515e-04 - loss: 0.0014 - val_accuracy: 0.0057 - val_loss: 3.8912e-04
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 4.5493e-04 - loss: 0.0013 - val_accuracy: 0.0057 - val_loss: 6.0437e-04
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 9.5838e-05 - loss: 0.0018 - val_accuracy: 0.0057 - val_loss: 4.2857e-04
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0015 - loss: 0.0013 - val_accuracy: 0.0057 - val_loss: 6.3489e-04
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 5.0439e-04 - loss: 0.0016 - val_accuracy: 0.0057 - val_loss: 7.4661e-04

# %%
import matplotlib.pyplot as plt

# Predict
predicted_gru = attention_model.predict(X_test)

# Inverse transform the predicted and actual values
predicted_gru_actual = target_scaler.inverse_transform(predicted_gru)  # Use target scaler for "high"
y_test_actual = target_scaler.inverse_transform(y_test.reshape(-1, 1))  # Reshape y_test to (num_samples, 1)

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label="Actual High Prices")
plt.plot(predicted_gru_actual, label="Predicted High Prices", alpha=0.7)
plt.legend()
plt.title("Actual vs Predicted High Prices")
plt.xlabel("Time")
plt.ylabel("High Prices")
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
# Evaluate the model
loss, accuracy = attention_model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")

# Visualize results
#import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0074 - loss: 2.8266e-04
# Test Accuracy: 0.01
