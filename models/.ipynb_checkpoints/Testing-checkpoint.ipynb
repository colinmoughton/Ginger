# %%
import pandas as pd

# %%
RR = pd.read_pickle("Screened_RR.pkl")

# %%
RR
# Out:
#                 open      high       low     close    volume  labels
# date
# 2020-03-04  637.0005  639.8005  604.2005  607.4005  46502239       0
# 2020-03-05  607.2005  614.0005  564.8005  587.2005  30602883       0
# 2020-03-06  572.0005  597.4005  566.0005  588.2005  30328645       0
# 2020-03-09  560.0005  579.0005  551.4005  568.2005  31554866       0
# 2020-03-10  567.6005  586.0005  550.4005  557.4005  33864988       0
# ...              ...       ...       ...       ...       ...     ...
# 2024-09-19  500.6000  526.2384  498.8913  525.0000  78255859       0
# 2024-09-20  518.8000  528.0000  517.2640  526.2000  79866781       0
# 2024-09-23  523.4000  532.8816  521.8000  530.2000  36149480       0
# 2024-09-24  532.2000  535.3519  520.4000  526.6000  15285780       0
# 2024-09-25  522.0000  532.0440  520.6000  531.8000  15307530       0
#
# [1151 rows x 6 columns]

# %%
RR.to_csv("RR.csv")

# %%
rolling_averages = RR.rolling(2).mean()

# %%
rolling_averages
# Out:
#                 open       high        low     close      volume  labels
# date
# 2020-03-04       NaN        NaN        NaN       NaN         NaN     NaN
# 2020-03-05  622.1005  626.90050  584.50050  597.3005  38552561.0     0.0
# 2020-03-06  589.6005  605.70050  565.40050  587.7005  30465764.0     0.0
# 2020-03-09  566.0005  588.20050  558.70050  578.2005  30941755.5     0.0
# 2020-03-10  563.8005  582.50050  550.90050  562.8005  32709927.0     0.0
# ...              ...        ...        ...       ...         ...     ...
# 2024-09-19  496.5500  511.71920  495.04565  510.5000  60195474.5     0.0
# 2024-09-20  509.7000  527.11920  508.07765  525.6000  79061320.0     0.0
# 2024-09-23  521.1000  530.44080  519.53200  528.2000  58008130.5     0.0
# 2024-09-24  527.8000  534.11675  521.10000  528.4000  25717630.0     0.0
# 2024-09-25  527.1000  533.69795  520.50000  529.2000  15296655.0     0.0
#
# [1151 rows x 6 columns]

# %%
#ratio_column ="close_ratio_2"
#RR[ratio_column] = RR["close"] / rolling_averages["close"]

# %%
# Apply standard scaling to all feature data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = RR.drop(["volume", "labels"], axis=1)
y = RR['labels']

X_scaled=scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled, columns=['open', 'high', 'low', 'close'])
#X_scaled
X_scaled
# Out:
#           open      high       low     close
# 0     3.508018  3.435098  3.359197  3.277874
# 1     3.270839  3.233361  3.038332  3.116855
# 2     2.990682  3.103562  3.048104  3.124827
# 3     2.895174  2.959687  2.929205  2.965402
# 4     2.955663  3.014422  2.921061  2.879313
# ...        ...       ...       ...       ...
# 1146  2.422405  2.547127  2.501581  2.621041
# 1147  2.567259  2.560901  2.651205  2.630606
# 1148  2.603871  2.599071  2.688145  2.662491
# 1149  2.673910  2.618387  2.676744  2.633795
# 1150  2.592728  2.592522  2.678372  2.675245
#
# [1151 rows x 4 columns]

# %%
RR["labels"].value_counts()
# Out:
# labels
# 0    1045
# 1     106
# Name: count, dtype: int64

# %%
! pip3 install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/dave/tf/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/dave/tf/lib/python3.10/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/dave/tf/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/dave/tf/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/dave/tf/lib/python3.10/site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=50, max_depth=10, min_samples_split=5, min_samples_leaf=1, criterion='entropy', random_state=1)

X_train = X_scaled.iloc[:-200]
X_test = X_scaled.iloc[-200:]

y_train = y.iloc[:-200]
y_test = y.iloc[-200:]


model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, min_samples_split=5,
#                        n_estimators=50, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(X_test)

# %%
preds = pd.Series(preds, index=test.index)

# %%
preds.value_counts()
# Out:
# 0    197
# 1      3
# Name: count, dtype: int64

# %%
precision_score(y_test, preds)
# Out:
# np.float64(0.0)

# %%
test["labels"].value_counts()
# Out:
# labels
# 0    183
# 1     17
# Name: count, dtype: int64

# %%
combined = pd.concat([y_test , preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='date'>
